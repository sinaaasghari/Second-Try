# %%
from google.colab import drive
drive.mount('/content/drive')
path='drive/MyDrive/Colab Notebooks/'
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Reading Data

# %%
df=pd.read_csv(path+'train_data.csv')
df
# Out:
# <ipython-input-8-2ba0a6b7beeb>:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(path+'train_data.csv')
#         overall vote  verified  reviewTime      reviewerID        asin style  \
# 0             2  NaN     False  2016-11-11   A2OSUEZJIN7BI  0511189877   NaN
# 1             5  NaN      True  2016-06-06  A2NETQRG6JHIG7  0511189877   NaN
# 2             4  NaN      True  2016-03-10  A12JHGROAX49G7  0511189877   NaN
# 3             5  NaN      True  2016-01-14  A1KV65E2TMMG6F  0511189877   NaN
# 4             5  NaN      True  2016-10-20  A280POPEWI0NSA  0594459451   NaN
# ...         ...  ...       ...         ...             ...         ...   ...
# 838939        5  NaN      True  2017-07-25  A1OOVLE2KZ6KGA  B01HJCN1EI   NaN
# 838940        1  NaN      True  2017-04-04   A77K1B31UAQ29  B01HJCN1EI   NaN
# 838941        3  NaN      True  2017-07-08  A2SVXUVUAWUDK2  B01HJH42KU   NaN
# ...

# %% [markdown]
# ### Similar Words for Guarantee and Warranty

# %%
guarantee_warranty_similars = ['guarantee',
  'garantee',
  'guarentee'
  'guarantie',
  'guarntee',
  'guarentee',
  'warranty',
  'waranty',
  'warrenty',
  'warrantee',
  'warentee',
  'warrnaty','guarantee','warranty','warraytee', 'warraneee', 'varrenty', 'wabrantee', 'guaranky', 'wsrrenty', 'guawantee', 'warrantw', 'guarantel', 'harrenty', 'warnenty', 'guyrantee', 'warranjee', 'guaraniy', 'warrenry', 'huarantee', 'warrerty', 'warraotee', 'guawanty', 'guazantee', 'warrepty', 'wahranty', 'sarranty', 'warrdnty', 'wareanty', 'warrsnty', 'darrantee', 'warrentf', 'warreity', 'warkanty', 'warmanty', 'warrantne', 'yarrenty', 'guaranwee', 'warrannee', 'warrantej', 'warrzntee', 'wafrantee', 'wakrantee', 'warianty', 'iuarantee', 'warrajty', 'gvarantee', 'fuaranty', 'zuaranty', 'warratty', 'guaranhy', 'earrenty', 'guarantze', 'guarentee', 'worranty', 'oarrenty', 'guarandy', 'guzranty', 'warrantu', 'worrantee', 'guaratty', 'warrantep', 'guapantee', 'zarrenty', 'harranty', 'warrakty', 'warrbntee', 'guarabtee', 'wlrrenty', 'guaranthe', 'wjrrenty', 'guarantez', 'warrvntee', 'warkenty', 'guarancee', 'parranty', 'guafanty', 'warrontee', 'guaranqee', 'warrarty', 'guxrantee', 'wayranty', 'warrantg', 'guaragty', 'guarantf', 'warragtee', 'guabantee', 'walrenty', 'guaravty', 'guaransee', 'guarantr', 'warfantee', 'guaranry', 'warrenxy', 'guaranjee', 'guarantee', 'tuaranty', 'warrentu', 'gsarantee', 'guahantee', 'warrewty', 'guacantee', 'guaranny', 'wprrantee','warraytee', 'warraneee', 'guarentej', 'guaranky', 'wabrantee', 'guawantee', 'warrantw', 'guarantel', 'guarebtee', 'guyrantee', 'warranjee', 'guaraniy', 'huarantee', 'warraotee', 'guawanty', 'guazantee', 'wahranty', 'sarranty', 'warrdnty', 'wareanty', 'warrsnty', 'guarentne', 'darrantee', 'warkanty', 'warrantne', 'warmanty', 'guaranwee', 'warrannee', 'warrantej', 'warrzntee', 'wafrantee', 'wakrantee', 'fuaranty', 'iuarantee', 'warianty', 'gvarantee', 'zuaranty', 'guarenbee', 'warrajty', 'warratty', 'guaranhy', 'guarantze', 'guarentee', 'worranty', 'gugrentee', 'guarandy', 'guzranty', 'worrantee', 'warrantep', 'guaratty', 'warrantu', 'guapantee', 'guarentde', 'harranty', 'warrakty', 'warrbntee', 'guarabtee', 'guaranthe', 'guarantez', 'warrvntee', 'guajentee', 'xuarentee', 'guarancee', 'guafanty', 'parranty', 'warrontee', 'guawentee', 'guaranqee', 'warrarty', 'guxrantee', 'guaragty', 'guarantf', 'warragtee', 'wayranty', 'warrantg', 'guabantee', 'glarentee', 'guaravty', 'guaransee', 'guarantr', 'warfantee', 'guaranry', 'guaranjee', 'guarantee', 'gjarentee', 'guaeentee', 'tuaranty', 'guarentqe', 'guarenaee', 'gsarantee', 'guahantee', 'guorentee', 'guarented', 'guacantee', 'gbarentee', 'guaranny', 'wprrantee', 'wcrrantee', 'guarenpee', 'guarantse']

# %%
len(guarantee_warranty_similars)
# Out:
# 213

# %% [markdown]
# ### Number of Reviews that contain the Words

# %%
df.reviewText.str.contains('|'.join(guarantee_warranty_similars)).sum()
# Out:
# 17240

# %%
filtered_df=df[df.reviewText.str.contains('|'.join(guarantee_warranty_similars))]
filtered_df
# Out:
#         overall vote  verified  reviewTime      reviewerID        asin  \
# 167           4  NaN      True  2016-08-04  A3IZBWYYS8J9YL  B000001OM4
# 253           3  3.0      True  2017-08-05  A1FTLC2RBYADR4  B00000J4EY
# 355           1  2.0      True  2017-05-22  A1KD8CHSA9ZFAO  B00000K2YR
# 389           1  NaN      True  2016-01-14  A20IQN5J9Z3I5N  B00000K2YR
# 454           5  8.0      True  2017-04-13  A2SFJ1ZN2HWL9M  B00001P505
# ...         ...  ...       ...         ...             ...         ...
# 838642        2  5.0      True  2018-02-28  A2N2CYJ67CEEVP  B01HEF8OV0
# 838691        5  NaN      True  2018-09-22  A21GK1G4CA6K9R  B01HEXFQVI
# 838854        1  6.0      True  2017-01-24  A3SLTZN1ZPGZ1W  B01HHRGSEA
# 838891        5  NaN     False  2016-12-04  A32O98PFC3OP7K  B01HIA63ZA
# 838901        3  7.0      True  2017-04-03   ALFU9DAR0IIHS  B01HIQYWU2
#
#                                                     style      reviewerName  \
# ...

# %% [markdown]
# ### Mean-Score of Filtered Data

# %%
filtered_df.groupby('reviewerID').agg({'overall':'mean'}).sort_values(by='overall',ascending=False)
# Out:
#                 overall
# reviewerID
# A30ESEDL8HT8BU      5.0
# A1XCBR65S5PS0Y      5.0
# A5JLAU2ARJ0BO       5.0
# A5KUVR7CG4V5V       5.0
# A2NC58AOXYOE69      5.0
# ...                 ...
# A3QL5ICE01GSP3      1.0
# A266C78RN39FC1      1.0
# A266Z0DC0SC67T      1.0
# A267BZU7LMUR31      1.0
# AZZYW4YOE1B6E       1.0
#
# [14758 rows x 1 columns]
