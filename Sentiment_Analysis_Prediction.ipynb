# %%
# !pip install transformers datasets evaluate accelerate

# %%
from google.colab import drive
drive.mount('/content/drive')
path='drive/MyDrive/Colab Notebooks/'
# Out:
# Mounted at /content/drive

# %%
from datasets import load_dataset
import numpy as np
import pandas as pd
test_data=load_dataset("OmidAghili/Sentiment_Analysis_Test")['train']
test_data
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# Generating train split:   0%|          | 0/20000 [00:00<?, ? examples/s]
# Dataset({
#     features: ['reviewText'],
#     num_rows: 20000
# })

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline
from huggingface_hub import login

login('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')

# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-classification", model="OmidAghili/Sentiment_Analysis_FinalModel")
label2id = {"EXTREMELY NEGATIVE": 0, "NEGATIVE": 1,"NEURAL":2,"POSITIVE":3, "EXTREMELY POSITIVE":4}

prediction=pipe(test_data['reviewText'],truncation=True)
prediction
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# config.json:   0%|          | 0.00/902 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'label': 'EXTREMELY NEGATIVE', 'score': 0.4727325439453125},
# ...

# %%
import datasets
q2_submission=pd.DataFrame([label2id[item['label']]+1 for item in prediction],columns=['predicted'])
out=datasets.Dataset.from_pandas(q2_submission)
out.push_to_hub("OmidAghili/Sentiment_Analysis_Prediction")

# %%
q2_submission
# Out:
#        predicted
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 19995          5
# 19996          5
# 19997          5
# 19998          1
# 19999          3
#
# [20000 rows x 1 columns]

# %%
q2_submission.to_csv(path+'q2_submission.csv',index=False)
